# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipo = pd.read_csv(url, sep = "\t")
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   str
#  3   choice_description  3376 non-null   str
#  4   item_price          4622 non-null   str
# dtypes: int64(2), str(3)
# memory usage: 490.3 KB

# %%
# mask = chipo["item_price"].str.replace("$","")
# mask
# chipo["item_price"] = pd.to_numeric(mask, errors="coerce")
# chipo["item_price"]

chipo["item_price"] = chipo["item_price"].apply(lambda x: float(x[1:]))
chipo["item_price"]
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
subset = chipo[chipo["item_price"] > 10]
subset["item_name"].nunique()
# Out:
# 31

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only three columns item_name choice_description and product_price

# %%
df = subset[["item_name","choice_description", "item_price"]]
df
# Out:
#                item_name                                 choice_description  \
# 4           Chicken Bowl  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5           Chicken Bowl  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 7          Steak Burrito  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 13          Chicken Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 23       Chicken Burrito  [[Tomatillo-Green Chili Salsa (Medium), Tomati...
# ...                  ...                                                ...
# 4610       Steak Burrito  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4611      Veggie Burrito  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...
# 4617       Steak Burrito  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618       Steak Burrito  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619  Chicken Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
#
#       item_price
# 4          16.98
# 5          10.98
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
df.sort_values(by = "item_name",inplace=True)
df
# Out:
#               item_name                                 choice_description  \
# 3389  6 Pack Soft Drink                                        [Diet Coke]
# 39        Barbacoa Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# 58        Barbacoa Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# 136       Barbacoa Bowl  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 471       Barbacoa Bowl  [[Tomatillo-Green Chili Salsa (Medium), Roaste...
# ...                 ...                                                ...
# 4201  Veggie Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Black...
# 4261  Veggie Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 738   Veggie Soft Tacos  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 1699  Veggie Soft Tacos  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 3889  Veggie Soft Tacos  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...
#
#       item_price
# 3389       12.98
# 39         11.75
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
expensive = chipo["item_price"].max()
answer = chipo[chipo["item_price"] == expensive]
answer.quantity
# Out:
# 3598    15
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
print(chipo[chipo["item_name"]=="Veggie Salad Bowl"]["quantity"].sum())
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo[(chipo["item_name"] == "Canned Soda") & (chipo["quantity"] > 1)].shape[0]
# Out:
# 20
