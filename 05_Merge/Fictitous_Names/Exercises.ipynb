# %% [markdown]
# # Fictitious Names

# %% [markdown]
# ### Introduction:
#
# This time you will create a data again
#
# Special thanks to [Chris Albon](http://chrisalbon.com/) for sharing the dataset and materials.
# All the credits to this exercise belongs to him.
#
# In order to understand about it go [here](https://blog.codinghorror.com/a-visual-explanation-of-sql-joins/).
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Create the 3 DataFrames based on the following raw data

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %% [markdown]
# ### Step 3. Assign each to a variable called data1, data2, data3

# %%
data1 = pd.DataFrame(raw_data_1)
data2 = pd.DataFrame(raw_data_2)
data3 = pd.DataFrame(raw_data_3)
data1
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %%
data2
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %% [markdown]
# ### Step 4. Join the two dataframes along rows and assign all_data

# %%
all_data = pd.concat([data1, data2])
all_data
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %% [markdown]
# ### Step 5. Join the two dataframes along columns and assing to all_data_col

# %%
all_data_col = pd.concat([data1, data2], axis=1)
all_data_col
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %% [markdown]
# ### Step 6. Print data3

# %%
data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %% [markdown]
# ### Step 7. Merge all_data and data3 along the subject_id value

# %%
data3.dtypes
# Out:
# subject_id      str
# test_id       int64
# dtype: object

# %%
all_data.dtypes
# Out:
# subject_id    str
# first_name    str
# last_name     str
# dtype: object

# %%
merge = all_data.join(data3, on="subject_id",how="left")
merge
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 merge = all_data.join(data3, on="subject_id",how="left")
#       2 merge
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:12800, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   12790     if how == "cross":
#   12791         return merge(
#   12792             self,
#   12793             other,
#    (...)  12798             validate=validate,
#   12799         )
# > 12800     return merge(
#   12801         self,
#   12802         other,
#   12803         left_on=on,
#   12804         how=how,
#   12805         left_index=on is None,
#   12806         right_index=True,
#   12807         suffixes=(lsuffix, rsuffix),
#   12808         sort=sort,
#   12809         validate=validate,
#   12810     )
#   12811 else:
#   12812     if on is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:385, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     371     return _cross_merge(
#     372         left_df,
#     373         right_df,
#    (...)    382         validate=validate,
#     383     )
#     384 else:
# --> 385     op = _MergeOperation(
#     386         left_df,
#     387         right_df,
#     388         how=how,
#     389         on=on,
#     390         left_on=left_on,
#     391         right_on=right_on,
#     392         left_index=left_index,
#     393         right_index=right_index,
#     394         sort=sort,
#     395         suffixes=suffixes,
#     396         indicator=indicator,
#     397         validate=validate,
#     398     )
#     399     return op.get_result()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:1031, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#    1027 self._validate_tolerance(self.left_join_keys)
#    1029 # validate the merge keys dtypes. We may need to coerce
#    1030 # to avoid incompatible dtypes
# -> 1031 self._maybe_coerce_merge_keys()
#    1033 # If argument passed to validate,
#    1034 # check if columns specified as unique
#    1035 # are in fact unique.
#    1036 if validate is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:1835, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1829     # unless we are merging non-string-like with string-like
#    1830     elif (
#    1831         inferred_left in string_types and inferred_right not in string_types
#    1832     ) or (
#    1833         inferred_right in string_types and inferred_left not in string_types
#    1834     ):
# -> 1835         raise ValueError(msg)
#    1837 # datetimelikes must match exactly
#    1838 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on str and int64 columns for key 'subject_id'. If you wish to proceed you should use pd.concat

# %% [markdown]
# ### Step 8. Merge only the data that has the same 'subject_id' on both data1 and data2

# %% [markdown]
# ### Step 9. Merge all values in data1 and data2, with matching records from both sides where available.
